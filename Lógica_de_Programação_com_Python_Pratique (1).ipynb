# %%
# Introdução: Explica para o User como funciona a calculadora, iniciando em 4 funções básicas:
# 1 para adição
# 2 para subração
# 3 para multiplicação e
# 4 para divisão

print("Para iniciar a calculadora, escolha o número da operação que deseja realizar:")
print('1 para Adição\n2 para Subtração\n3 para Multiplicação e \n4 para Divisão')

# Recebe a operação desejada transformando ela em integer
operacao = int(input("Qual operação deseja realizar? "))

# Lista os valores de operações disponíveis
operacao_valida = {1, 2, 3, 4}

# Recebe os dois números desejados e transforma eles em integer
if operacao in operacao_valida:
  num1 = int(input("Qual é o primeiro número? "))
  num2 = int(input("Qual é o segundo número? "))

# realiza a operação de adição
if operacao == 1:
  resultado = num1 + num2
  print("A soma é: ", resultado)

# realiza a operação de subtração
elif operacao == 2:
  resultado = num1 - num2
  print("A diferença é: ", resultado)

# realiza a operação de multiplicação
elif operacao == 3:
  resultado = num1 * num2
  print("O produto é: ", resultado)

# realiza a operação de divisão e confere se existe resto
elif operacao == 4:
  resultado = num1 / num2
  resto = num1 % num2

# se não existe resto, transforma em integer, se não, mantem como float.
  if resto == 0:
    print("O resultado é: ", (int(resultado)))
  else:
    print("O resultado é: ", resultado)

else:
  print("\nEste número não é válido, por favor inicie novamente e insira uma operação disponível")

# Registra novas variáveis (ainda não encontrei um jeito de fazer o código
# rodar sem apresentar elas antes)

num_potenciado = 0
potencia = 0

print("\nPara continuar, vamos elevar um numero na potencia de sua escolha.")

operacao2 = int(input("\nDigite 1 para continuar "))

lista_repeticao = [1]

if operacao2 in lista_repeticao:
  num_potenciado = int(input("Digite o número: "))
  potencia = int(input("Digite sua potência: "))


# atribui uma nova variável para manter o número original e não transformmar o
# número em algo enorme:

  base = num_potenciado

# repete a operação em quantas vezes forem necessárias. Sim, existe uma forma mais
# simples de fazer potenciação no python, mas essa foi a forma que encontrei de
# aplicar a repetição com o while hehe

  if operacao2 == 1:
    contador = potencia
    while contador > 1:
      num_potenciado = num_potenciado * base
      contador -= 1

    else:
      print("O resultado de ", base, " em sua ", potencia, "ª potência é: ", num_potenciado)

else:
  print("Operação não disponível.")
